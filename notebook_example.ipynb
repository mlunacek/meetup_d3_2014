# %% [markdown]
# ## A Quick Notebook Example
#
# - You can add `Markdown`.
# - `Latex` $c = \sqrt{a^2 + b^2}$.

# %%
import numpy as np
x = np.random.randn(100)

# %% [markdown]
# What does `x` look like?

# %%
print x[:10]
# Out:
# [ 0.34517199  0.52042377 -0.7593485  -1.44755648 -0.58321943 -1.80316233
#  -1.04843808  0.0657665  -0.64083872  0.76542537]

# %% [markdown]
# Histogram?

# %%
hist(x)
show()

# %% [markdown]
# What about something **interactive**?

# %%
import smash
import os
import pandas as pd

# %%
smash.initialize()

# %%
df = pd.read_csv(os.path.join('data','cars.csv'))
print df.head()
# Out:
#                       name  economy (mpg)  cylinders  displacement (cc)  \
# 0  AMC Ambassador Brougham           13.0          8                360
# 1       AMC Ambassador DPL           15.0          8                390
# 2       AMC Ambassador SST           17.0          8                304
# 3         AMC Concord DL 6           20.2          6                232
# 4           AMC Concord DL           18.1          6                258
#
#    power (hp)  weight (lb)  0-60 mph (s)  year
# 0         175         3821          11.0    73
# 1         190         3850           8.5    70
# 2         150         3672          11.5    72
# 3          90         3265          18.2    79
# 4         120         3410          15.1    78

# %%
smash.parallel(data=df).show()
# Out:
# <style type="text/css">
# svg {
#   font: 10px sans-serif;
# }
#
# .background path {
#   fill: none;
#   stroke: #ccc;
#   stroke-opacity: .4;
#   shape-rendering: crispEdges;
# }
#
# .foreground path {
#   fill: none;
#   stroke: #8a89a6;
#   stroke-opacity: .7;
# }
#
# .brush .extent {
#   fill-opacity: .3;
#   stroke: #fff;
#   shape-rendering: crispEdges;
# }
#
# .axis line, .axis path {
#   fill: none;
#   stroke: #000;
#   shape-rendering: crispEdges;
# }
#
# .axis text {
#   text-shadow: 0 1px 0 #fff;
#   cursor: move;
# }
# </style>
# <div id="vis31322"></div>
# <script src="http://d3js.org/d3.v2.min.js"></script>
# <!--     // <script type="text/javascript" src="http://mbostock.github.com/d3/d3.js?2.5.0"></script>
#     // <script type="text/javascript" src="http://mbostock.github.com/d3/d3.csv.js?2.5.0"></script> -->
#     <script type="text/javascript">
#
# var m = [30, 10, 10, 10],
#     w = 800 - m[1] - m[3],
#     h = 300 - m[0] - m[2];
#
# ...
